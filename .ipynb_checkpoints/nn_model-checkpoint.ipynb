# %%
import tensorflow as tf
import pandas as pd
import datetime
import numpy as np
import os
from tensorflow.python import pywrap_tensorflow

# %% [markdown]
# ## Preprocessing

# %%
'''
PARAMETERS TO CHANGE
'''
stock_symbol = 'bac'
train_model = True
test_model = True
''''''

training_data_dir = './training_data/'
y_columns = ['ppo', 'rsi']
#assert(train_model ^ test_model)
model_dir = "./regularizer_models/" + stock_symbol + '/'

if train_model:
    training_data = pd.read_csv(training_data_dir + stock_symbol + '_training_data.csv')
    unneeded_columns = ['window']

    x_columns = list(training_data.columns)
    for to_remove in (y_columns + unneeded_columns):
        x_columns.remove(to_remove)

    train_x = training_data[x_columns].values
    train_y = training_data[y_columns].values

    model_dir = "./regularizer_models/" + stock_symbol + '/'

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
        
if test_model:
    test_data = pd.read_csv(training_data_dir + stock_symbol + '_test_data.csv')
    
    unneeded_columns = ['Date_to_use_on']
    x_columns = list(test_data.columns)

    for to_remove in (unneeded_columns):
        x_columns.remove(to_remove)

    
    test_x = test_data[x_columns].values

# %% [markdown]
# ## ANN Model

# %%
# Parameters
learning_rate = 0.1
num_epochs = 30000
batch_size = 128
display_epoch = 100

# Network Parameters
n_hidden_1 = 256 # 1st layer number of neurons
n_hidden_2 = 256 # 2nd layer number of neurons
num_input = len(x_columns) # Number of features
num_output = len(y_columns) # PPO, RSI parameters


def ANN(X):
    # Store layers weight & bias
    weights = {
        'h1': tf.Variable(tf.random_normal([num_input, n_hidden_1])),
        'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
        'out': tf.Variable(tf.random_normal([n_hidden_2, num_output]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([n_hidden_1])),
        'b2': tf.Variable(tf.random_normal([n_hidden_2])),
        'out': tf.Variable(tf.random_normal([num_output]))
    }

    # Hidden fully connected layer with 256 neurons
    layer_1 = tf.add(tf.matmul(X, weights['h1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)    
    
    # Hidden fully connected layer with 256 neurons
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    
    
    # Output fully connected layer with a neuron for each output
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    out = tf.square(out_layer)
    
    return out

X = tf.placeholder("float", [None, num_input])
Y = tf.placeholder("float", [None, num_output])

output = ANN(X)

# Loss & Optimizer
loss_op = tf.losses.mean_squared_error(Y, output, weights=1)
train_op = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss_op)
# Accuracy
accuracy =  tf.abs(tf.reduce_mean(tf.round(output) - Y))

# %%
if train_model:

    # Initialize the variables (i.e. assign their default value)
    init = tf.global_variables_initializer()

    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        # Run initializer
        sess.run(init)
        for epoch in range(num_epochs):
            sess.run(train_op, feed_dict={X: train_x, Y: train_y})

            if epoch % display_epoch == 0 or epoch == 1:
                loss, acc = sess.run([loss_op, accuracy], feed_dict={X: train_x, Y: train_y})

                print("Epoch " + str(epoch) + ", Loss= " + \
                      "{:.4f}".format(loss) + ", Training Error= " + \
                      "{:.3f}".format(acc))

            if acc <= 0.05:
                break
        print(sess.run(output, feed_dict={X: train_x}))
        saver.save(sess, model_dir + stock_symbol + '_regularizer.ckpt')
        
        
        print('Model Saved')
# Out:
# Epoch 0, Loss= 522119118848.0000, Training Error= 654654.875
# Epoch 1, Loss= 1124738048.0000, Training Error= 31344.281
# Epoch 100, Loss= 93329.7891, Training Error= 129.490
# Epoch 200, Loss= 58673.6094, Training Error= 113.453
# Epoch 300, Loss= 44057.7734, Training Error= 101.627
# Epoch 400, Loss= 34893.2773, Training Error= 92.004
# Epoch 500, Loss= 28434.3438, Training Error= 83.932
# Epoch 600, Loss= 23642.6074, Training Error= 77.025
# Epoch 700, Loss= 19956.5352, Training Error= 71.033
# Epoch 800, Loss= 17007.9219, Training Error= 65.686
# Epoch 900, Loss= 14616.9482, Training Error= 60.896
# Epoch 1000, Loss= 12584.3477, Training Error= 56.564
# Epoch 1100, Loss= 10887.7793, Training Error= 52.651
# Epoch 1200, Loss= 9509.7764, Training Error= 49.159
# Epoch 1300, Loss= 8358.4717, Training Error= 45.998
# Epoch 1400, Loss= 7391.2119, Training Error= 43.112
# Epoch 1500, Loss= 6571.8433, Training Error= 40.476
# Epoch 1600, Loss= 5877.7725, Training Error= 38.074
# Epoch 1700, Loss= 5280.6821, Training Error= 35.876
# Epoch 1800, Loss= 4767.3755, Training Error= 33.894
# Epoch 1900, Loss= 4318.2090, Training Error= 32.073
# Epoch 2000, Loss= 3925.1780, Training Error= 30.409
# Epoch 2100, Loss= 3578.0801, Training Error= 28.867
# Epoch 2200, Loss= 3272.6191, Training Error= 27.457
# Epoch 2300, Loss= 3002.6030, Training Error= 26.150
# Epoch 2400, Loss= 2763.3340, Training Error= 24.961
# Epoch 2500, Loss= 2549.2544, Training Error= 23.844
# Epoch 2600, Loss= 2356.3845, Training Error= 22.820
# Epoch 2700, Loss= 2184.5654, Training Error= 21.872
# Epoch 2800, Loss= 2030.4679, Training Error= 20.989
# Epoch 2900, Loss= 1888.8749, Training Error= 20.157
# Epoch 3000, Loss= 1748.3236, Training Error= 19.308
# Epoch 3100, Loss= 1620.9358, Training Error= 18.519
# Epoch 3200, Loss= 1504.6299, Training Error= 17.762
# Epoch 3300, Loss= 1395.1117, Training Error= 17.021
# Epoch 3400, Loss= 1295.8868, Training Error= 16.324
# Epoch 3500, Loss= 1208.2004, Training Error= 15.695
# Epoch 3600, Loss= 1129.2026, Training Error= 15.120
# Epoch 3700, Loss= 1055.8710, Training Error= 14.554
# Epoch 3800, Loss= 988.3502, Training Error= 14.020
# Epoch 3900, Loss= 926.4403, Training Error= 13.516
# Epoch 4000, Loss= 868.9567, Training Error= 13.032
# Epoch 4100, Loss= 816.1130, Training Error= 12.567
# Epoch 4200, Loss= 767.5085, Training Error= 12.120
# Epoch 4300, Loss= 722.3920, Training Error= 11.703
# Epoch 4400, Loss= 680.8934, Training Error= 11.295
# Epoch 4500, Loss= 642.5291, Training Error= 10.914
# Epoch 4600, Loss= 606.2181, Training Error= 10.550
# Epoch 4700, Loss= 573.3167, Training Error= 10.190
# Epoch 4800, Loss= 542.0895, Training Error= 9.866
# Epoch 4900, Loss= 512.1791, Training Error= 9.542
# Epoch 5000, Loss= 484.4672, Training Error= 9.229
# Epoch 5100, Loss= 458.7179, Training Error= 8.930
# Epoch 5200, Loss= 434.4763, Training Error= 8.629
# Epoch 5300, Loss= 411.6469, Training Error= 8.350
# Epoch 5400, Loss= 390.2028, Training Error= 8.080
# Epoch 5500, Loss= 370.1122, Training Error= 7.827
# Epoch 5600, Loss= 351.3128, Training Error= 7.574
# Epoch 5700, Loss= 333.6774, Training Error= 7.332
# Epoch 5800, Loss= 316.5316, Training Error= 7.094
# Epoch 5900, Loss= 300.3021, Training Error= 6.857
# Epoch 6000, Loss= 284.9064, Training Error= 6.625
# Epoch 6100, Loss= 270.6636, Training Error= 6.400
# Epoch 6200, Loss= 257.3676, Training Error= 6.187
# Epoch 6300, Loss= 244.9282, Training Error= 5.986
# Epoch 6400, Loss= 233.3254, Training Error= 5.787
# Epoch 6500, Loss= 222.3520, Training Error= 5.601
# Epoch 6600, Loss= 211.9379, Training Error= 5.406
# Epoch 6700, Loss= 202.0665, Training Error= 5.224
# Epoch 6800, Loss= 192.7690, Training Error= 5.043
# Epoch 6900, Loss= 183.7830, Training Error= 4.860
# Epoch 7000, Loss= 175.3294, Training Error= 4.682
# Epoch 7100, Loss= 167.3385, Training Error= 4.519
# Epoch 7200, Loss= 159.8601, Training Error= 4.348
# Epoch 7300, Loss= 152.8348, Training Error= 4.191
# Epoch 7400, Loss= 146.2849, Training Error= 4.043
# Epoch 7500, Loss= 140.0093, Training Error= 3.902
# Epoch 7600, Loss= 134.1243, Training Error= 3.755
# Epoch 7700, Loss= 128.5754, Training Error= 3.614
# Epoch 7800, Loss= 123.3613, Training Error= 3.481
# Epoch 7900, Loss= 118.3021, Training Error= 3.349
# Epoch 8000, Loss= 113.5589, Training Error= 3.209
# Epoch 8100, Loss= 109.0692, Training Error= 3.089
# Epoch 8200, Loss= 104.8541, Training Error= 2.962
# Epoch 8300, Loss= 100.8460, Training Error= 2.838
# Epoch 8400, Loss= 97.0086, Training Error= 2.719
# Epoch 8500, Loss= 93.3483, Training Error= 2.613
# Epoch 8600, Loss= 89.8780, Training Error= 2.491
# Epoch 8700, Loss= 86.5839, Training Error= 2.382
# Epoch 8800, Loss= 83.4396, Training Error= 2.279
# Epoch 8900, Loss= 80.4312, Training Error= 2.168
# Epoch 9000, Loss= 77.5200, Training Error= 2.066
# Epoch 9100, Loss= 74.8167, Training Error= 1.964
# Epoch 9200, Loss= 72.2679, Training Error= 1.868
# Epoch 9300, Loss= 69.8787, Training Error= 1.779
# Epoch 9400, Loss= 67.5814, Training Error= 1.691
# Epoch 9500, Loss= 65.4098, Training Error= 1.598
# Epoch 9600, Loss= 63.2896, Training Error= 1.517
# Epoch 9700, Loss= 61.2539, Training Error= 1.433
# Epoch 9800, Loss= 59.3333, Training Error= 1.357
# Epoch 9900, Loss= 57.5285, Training Error= 1.276
# Epoch 10000, Loss= 55.8283, Training Error= 1.205
# Epoch 10100, Loss= 54.2057, Training Error= 1.128
# Epoch 10200, Loss= 52.6779, Training Error= 1.053
# Epoch 10300, Loss= 51.2282, Training Error= 0.988
# Epoch 10400, Loss= 49.8716, Training Error= 0.925
# Epoch 10500, Loss= 48.5874, Training Error= 0.862
# Epoch 10600, Loss= 47.3910, Training Error= 0.808
# Epoch 10700, Loss= 46.2563, Training Error= 0.742
# Epoch 10800, Loss= 45.1454, Training Error= 0.685
# Epoch 10900, Loss= 44.0085, Training Error= 0.629
# Epoch 11000, Loss= 42.9500, Training Error= 0.578
# Epoch 11100, Loss= 41.9554, Training Error= 0.526
# Epoch 11200, Loss= 41.0111, Training Error= 0.481
# Epoch 11300, Loss= 40.1040, Training Error= 0.426
# Epoch 11400, Loss= 39.2296, Training Error= 0.378
# Epoch 11500, Loss= 38.4021, Training Error= 0.331
# Epoch 11600, Loss= 37.6172, Training Error= 0.291
# Epoch 11700, Loss= 36.8497, Training Error= 0.250
# Epoch 11800, Loss= 36.1168, Training Error= 0.206
# Epoch 11900, Loss= 35.4164, Training Error= 0.169
# Epoch 12000, Loss= 34.7499, Training Error= 0.133
# Epoch 12100, Loss= 34.1171, Training Error= 0.094
# Epoch 12200, Loss= 33.5157, Training Error= 0.057
# Epoch 12300, Loss= 32.9468, Training Error= 0.021
# [[1.8231258e+00 1.7442820e+00]
#  [2.9907098e+00 4.4682980e-02]
#  [7.8875318e+00 7.2897831e-03]
#  ...
#  [3.4831583e+00 3.1102243e-01]
#  [6.3874497e+00 1.2385085e+01]
#  [2.2075471e-01 1.0863130e+00]]
# Model Saved

# %%
if test_model:
    
    saver = tf.train.Saver()
    with tf.Session() as sess:
        '''var_name_list = [v.name for v in tf.trainable_variables()]
        print(var_name_list)
        
        reader = pywrap_tensorflow.NewCheckpointReader(model_dir + stock_symbol + '_regularizer.ckpt')
        var_to_shape_map = reader.get_variable_to_shape_map()'''
        
        saver.restore(sess, model_dir + stock_symbol + '_regularizer.ckpt')
        print("Model restored.")
        predicted = tf.round(sess.run(output, feed_dict={X : test_x})).eval()
        predicted = np.array(predicted)
        
    result = pd.DataFrame(predicted, columns = y_columns)
    result['Date_to_use_on'] = test_data['Date_to_use_on']
    result = result[['Date_to_use_on'] + y_columns]
    result.to_csv(training_data_dir+ stock_symbol + '_test_parameters.csv', index=False)
# Out:
# INFO:tensorflow:Restoring parameters from ./regularizer_models/bac/bac_regularizer.ckpt
# Model restored.

# %%
result
# Out:
#     Date_to_use_on    ppo    rsi
# 0       2009-11-20    4.0    6.0
# 1       2009-11-23    1.0    1.0
# 2       2009-11-24    5.0   10.0
# 3       2009-11-25    1.0    1.0
# 4       2009-11-27    1.0    1.0
# 5       2009-11-30    1.0    7.0
# 6       2009-12-01    1.0    5.0
# 7       2009-12-02    1.0    4.0
# 8       2009-12-03    2.0    2.0
# 9       2009-12-04    1.0    1.0
# 10      2009-12-07  123.0   34.0
# 11      2009-12-08  123.0  104.0
# 12      2009-12-09  316.0    1.0
# 13      2009-12-10  218.0  452.0
# 14      2009-12-11   72.0   36.0
# 15      2009-12-14    1.0   11.0
# 16      2009-12-15  353.0   10.0
# 17      2009-12-16  580.0  126.0
# 18      2009-12-17  153.0   10.0
# 19      2009-12-18    1.0   64.0
# 20      2009-12-21    1.0    7.0
# 21      2009-12-22   22.0    6.0
# 22      2009-12-23  129.0   74.0
# 23      2009-12-24   60.0    4.0
# 24      2009-12-28    6.0   23.0
# 25      2009-12-29  166.0  108.0
# 26      2009-12-30   24.0   97.0
# 27      2009-12-31  156.0  145.0
# 28      2010-01-04   17.0   21.0
# 29      2010-01-05  106.0  172.0
# ..             ...    ...    ...
# 645     2012-06-14    2.0    1.0
# 646     2012-06-15    1.0    1.0
# 647     2012-06-18   12.0    4.0
# 648     2012-06-19    2.0    1.0
# 649     2012-06-20    1.0    2.0
# 650     2012-06-21    2.0    1.0
# 651     2012-06-22    3.0    7.0
# 652     2012-06-25    1.0    4.0
# 653     2012-06-26    2.0    5.0
# 654     2012-06-27    1.0    3.0
# 655     2012-06-28    7.0    1.0
# 656     2012-06-29    3.0    3.0
# 657     2012-07-02    1.0    3.0
# 658     2012-07-03    1.0    2.0
# 659     2012-07-05    6.0    1.0
# 660     2012-07-06    1.0    1.0
# 661     2012-07-09    3.0    1.0
# 662     2012-07-10    4.0    2.0
# 663     2012-07-11    1.0    4.0
# 664     2012-07-12    4.0   14.0
# 665     2012-07-13    1.0    1.0
# 666     2012-07-16    8.0    3.0
# 667     2012-07-17    1.0    1.0
# 668     2012-07-18    2.0    2.0
# 669     2012-07-19   12.0    2.0
# 670     2012-07-20    1.0    8.0
# 671     2012-07-23    7.0    2.0
# 672     2012-07-24    2.0    6.0
# 673     2012-07-25    3.0    1.0
# 674     2012-07-26    3.0    6.0
#
# [675 rows x 3 columns]
